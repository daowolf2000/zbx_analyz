# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library: 
##from (library) import (specific library function)
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# Enable inline plotting
# %matplotlib inline

# %%
events = pd.read_excel('events.xlsx')
objects = pd.read_excel('objects.xlsx')

# %%
events
# Out:
#       type                  model          address  \
# 0       ИБ  Cisco Catalyst C2960X  ДГУ - Океанский
# 1       ИБ  Cisco Catalyst C2960X  ДГУ - Океанский
# 2       ИБ  Cisco Catalyst C2960X  ДГУ - Океанский
# 3       ИБ  Cisco Catalyst C2960X  ДГУ - Океанский
# 4       ИБ  Cisco Catalyst C2960X  ДГУ - Океанский
# ...    ...                    ...              ...
# 5950  СКСД     Vmware vCenter 5.5  Якутия - Якутск
# 5951  СКСД     Vmware vCenter 5.5  Якутия - Якутск
# 5952  СКСД     Vmware vCenter 5.5  Якутия - Якутск
# 5953  СКСД     Vmware vCenter 5.5  Якутия - Якутск
# 5954  СКСД     Vmware vCenter 5.5  Якутия - Якутск
#
#                                            event  level               start  \
# 0     [#Manual] PortSecurity - Заблокирован порт      2 2024-01-23 15:10:02
# 1     [#Manual] PortSecurity - Заблокирован порт      2 2024-01-23 15:08:34
# 2     [#Manual] PortSecurity - Заблокирован порт      2 2024-01-22 14:44:22
# 3     [#Manual] PortSecurity - Заблокирован порт      2 2024-01-15 11:59:21
# 4     [#Manual] PortSecurity - Заблокирован порт      2 2024-01-15 11:59:16
# ...                                          ...    ...                 ...
# 5950                     Высокая загрузка памяти      2 2024-03-29 15:50:56
# 5951                     Высокая загрузка памяти      2 2024-03-29 15:50:54
# 5952     Индикация предупреждения на гипервизоре      2 2024-03-29 15:46:35
# 5953     Индикация предупреждения на гипервизоре      2 2024-03-29 15:46:32
# 5954     Индикация предупреждения на гипервизоре      2 2024-03-29 15:46:30
#
#       duration                               object      tu  \
# 0        85803                         0-3-3-C2960X     ДГУ
# 1        85891                         0-3-3-C2960X     ДГУ
# 2        68143                         0-3-3-C2960X     ДГУ
# 3         7844                         0-3-3-C2960X     ДГУ
# 4         7849                         0-3-3-C2960X     ДГУ
# ...        ...                                  ...     ...
# 5950    132600  Якутия - Якутск / СКСД (S98VCENTER)  Якутия
# 5951    132600  Якутия - Якутск / СКСД (S98VCENTER)  Якутия
# 5952        12  Якутия - Якутск / СКСД (S98VCENTER)  Якутия
# 5953        12  Якутия - Якутск / СКСД (S98VCENTER)  Якутия
# 5954        12  Якутия - Якутск / СКСД (S98VCENTER)  Якутия
#
#                      end
# 0    2024-01-24 15:00:05
# 1    2024-01-24 15:00:05
# 2    2024-01-23 09:40:05
# 3    2024-01-15 14:10:05
# 4    2024-01-15 14:10:05
# ...                  ...
# 5950 2024-03-31 04:40:56
# 5951 2024-03-31 04:40:54
# 5952 2024-03-29 15:46:47
# 5953 2024-03-29 15:46:44
# 5954 2024-03-29 15:46:42
#
# [5955 rows x 10 columns]

# %%
objects
# Out:
#                                                  object         tu  \
# 0              Анадырь - Дежнева / Сервер (s77srkias01)    Анадырь
# 1              Анадырь - Дежнева / Сервер (s77srkiod01)    Анадырь
# 2              Анадырь - Дежнева / Сервер (S77SRKUPR01)    Анадырь
# 3     Анадырь - Дежнева / Ленточная библиотека (S77S...    Анадырь
# 4     Анадырь - Дежнева / Ленточная библиотека (S77S...    Анадырь
# ...                                                 ...        ...
# 1173           ДГУ - ЛВС - Светланская 71 / C3550-48_01        ДГУ
# 1174      ДГУ - ЛВС - Светланская 71 / c3548XL_02_TND48        ДГУ
# 1175                  ДГУ - Светланская 71 / 17 (iNode)        ДГУ
# 1176          ДГУ - Светланская 111 / Серверная (ИБП 1)        ДГУ
# 1177       Хабаровск - Воронежская / 2212 (Температура)  Хабаровск
#
#                       address                  type          model  \
# 0           Анадырь - Дежнева     Физический сервер    HP DL380 G7
# 1           Анадырь - Дежнева     Физический сервер    HP DL380 G7
# 2           Анадырь - Дежнева     Физический сервер    HP DL380 G7
# 3           Анадырь - Дежнева  Ленточная библиотека    HP D2D4009i
# 4           Анадырь - Дежнева  Ленточная библиотека    HP D2D4009i
# ...                       ...                   ...            ...
# 1173          ДГУ - Океанский                Прочее      Узел сети
# 1174          ДГУ - Океанский                Прочее      Узел сети
# 1175     ДГУ - Светланская 71    Web/SNMP - адаптер    iNode-Light
# 1176    ДГУ - Светланская 111                   ИБП  APC Smart-UPS
# 1177  Хабаровск - Воронежская    Web/SNMP - адаптер        Uniping
#
#                 date_add
# 0    2024-03-28 00:00:00
# 1    2024-03-28 00:00:00
# 2    2024-03-28 00:00:00
# 3    2024-03-28 00:00:00
# 4    2024-03-28 00:00:00
# ...                  ...
# 1173 2023-07-01 19:08:32
# 1174 2023-07-01 19:08:32
# 1175 2023-07-01 19:08:32
# 1176 2023-07-01 19:08:32
# 1177 2023-07-01 19:08:32
#
# [1178 rows x 6 columns]
